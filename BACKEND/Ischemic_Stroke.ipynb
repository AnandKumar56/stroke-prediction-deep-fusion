# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import random
import pickle

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv(r"../DATASET/brain_stroke.csv")
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status', 'stroke']

# %% [markdown]
# 1) gender: "Male", "Female" or "Other"
#
# 2) age: age of the patient
#
# 3) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
#
# 4) heart disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease 5) Ever-married: "No" or "Yes"
#
# 6) work type: "children", "Govtjov", "Never worked", "Private" or "Self-employed"
#
# 7) Residencetype: "Rural" or "Urban"
#
# 8) avg glucose level: average glucose level in blood
#
# 9) BMI: body mass index
#
# 10) smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
#
# 11) stroke: 1 if the patient had a stroke or 0 if not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
df["stroke"].value_counts()
# Out:
# stroke
# 0    4733
# 1     248
# Name: count, dtype: int64

# %%
from sklearn.utils import resample
# Separate majority and minority classes
# Converting 'stroke' to numeric before filtering
df['stroke'] = pd.to_numeric(df['stroke'], errors='coerce')

df_majority = df[df['stroke'] == 0]
df_minority = df[df['stroke'] == 1]

# Downsample majority class and upsample the minority class
df_minority_upsampled = resample(df_minority, replace=True, n_samples=4000, random_state=100)
df_majority_downsampled = resample(df_majority, replace=True, n_samples=4000, random_state=100)

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_minority_upsampled, df_majority_downsampled])

# Display new class counts
df_balanced['stroke'].value_counts()
# Out:
# stroke
# 1    4000
# 0    4000
# Name: count, dtype: int64

# %%
df = df_balanced

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
le = LabelEncoder()

# List of columns that are of type 'object' (categorical features)
object_cols = df.select_dtypes(include=['object']).columns

# Convert all object-type columns to string (to handle mixed types)
for col in object_cols:
    df[col] = df[col].astype(str)  # Ensure all data in the column is treated as string

# Apply label encoding to each object-type column
for col in object_cols:
    df[col] = le.fit_transform(df[col])

# Check the result (first few rows)
print(df.head())
# Out:
#      gender   age  hypertension  heart_disease  ever_married  work_type  \
# 8         0  81.0             1              0             1          1
# 24        1  57.0             1              0             1          1
# 67        0  68.0             1              0             0          2
# 103       1  56.0             1              0             1          1
# 87        0  57.0             0              0             1          0
#
#      Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 8                 0              80.43  29.7               2       1
# 24                1             212.08  44.2               3       1
# 67                1              79.79  29.7               2       1
# 103               0             249.31  35.8               2       1
# 87                1             110.52  28.5               0       1

# %%
df.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000  0.025080      0.009527       0.132434
# age                0.025080  1.000000      0.264137       0.267060
# hypertension       0.009527  0.264137      1.000000       0.083510
# heart_disease      0.132434  0.267060      0.083510       1.000000
# ever_married       0.041141  0.557315      0.087717       0.066755
# work_type          0.040746 -0.287421     -0.003522      -0.063355
# Residence_type    -0.009660  0.018222     -0.007367       0.025359
# avg_glucose_level  0.118891  0.275511      0.146584       0.260343
# bmi                0.020626  0.236305      0.101440       0.063601
# smoking_status    -0.043118  0.184728      0.140752       0.090577
# stroke             0.024580  0.569862      0.221618       0.214740
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                 0.041141   0.040746       -0.009660           0.118891
# age                    0.557315  -0.287421        0.018222           0.275511
# hypertension           0.087717  -0.003522       -0.007367           0.146584
# heart_disease          0.066755  -0.063355        0.025359           0.260343
# ever_married           1.000000  -0.295554       -0.047859           0.191441
# work_type             -0.295554   1.000000        0.013016          -0.114675
# Residence_type        -0.047859   0.013016        1.000000           0.031880
# avg_glucose_level      0.191441  -0.114675        0.031880           1.000000
# bmi                    0.294804  -0.268897        0.007853           0.268539
# smoking_status         0.195406  -0.225640       -0.021407           0.077403
# stroke                 0.280766  -0.104454        0.031315           0.250170
#
#                         bmi  smoking_status    stroke
# gender             0.020626       -0.043118  0.024580
# age                0.236305        0.184728  0.569862
# hypertension       0.101440        0.140752  0.221618
# heart_disease      0.063601        0.090577  0.214740
# ever_married       0.294804        0.195406  0.280766
# work_type         -0.268897       -0.225640 -0.104454
# Residence_type     0.007853       -0.021407  0.031315
# avg_glucose_level  0.268539        0.077403  0.250170
# bmi                1.000000        0.164174  0.136838
# smoking_status     0.164174        1.000000  0.060221
# stroke             0.136838        0.060221  1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of Correlations',fontsize=15)
plt.show()

# %%
x = df.drop(columns=['stroke'])
y = df['stroke']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

#from sklearn.preprocessing import StandardScaler
#scaler=StandardScaler()
#x_train=scaler.fit_transform(x_train)
#x_test=scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (6000, 10)

# %%
import numpy as np

# Reshape the data for CNN
x_train_cnn = np.expand_dims(x_train, axis=2)  # Adding a channel dimension
x_test_cnn = np.expand_dims(x_test, axis=2)

# %%
# First lets add the necessary import for Label Encoding the y values
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.preprocessing import LabelEncoder

# Define the CNN model
def build_cnn_model(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', padding='same', input_shape=input_shape), #Added padding='same'
        MaxPooling1D(pool_size=2),
        Conv1D(32, kernel_size=3, activation='relu', padding='same'), #Added padding='same'
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Encode the y values
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Build the model
cnn_model = build_cnn_model((x_train_cnn.shape[1], 1))

import pickle
pickle.dump(cnn_model, open(r'../FRONTEND/cnn.pkl', 'wb'))

#Print the summary after the model has been made
print(cnn_model.summary())

# Train the model
history_cnn = cnn_model.fit(x_train_cnn, y_train, validation_split=0.2, epochs=100, batch_size=32)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None,
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7921 - loss: 0.4330 - val_accuracy: 0.7600 - val_loss: 0.4738
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7858 - loss: 0.4422 - val_accuracy: 0.7567 - val_loss: 0.4790
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7892 - loss: 0.4348 - val_accuracy: 0.7558 - val_loss: 0.4672
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7865 - loss: 0.4378 - val_accuracy: 0.7742 - val_loss: 0.4643
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7915 - loss: 0.4377 - val_accuracy: 0.7542 - val_loss: 0.4813
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7885 - loss: 0.4380 - val_accuracy: 0.7575 - val_loss: 0.4803
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7915 - loss: 0.4387 - val_accuracy: 0.7583 - val_loss: 0.4639
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7925 - loss: 0.4331 - val_accuracy: 0.7242 - val_loss: 0.4930
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7875 - loss: 0.4350 - val_accuracy: 0.7567 - val_loss: 0.4635
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7946 - loss: 0.4310 - val_accuracy: 0.7642 - val_loss: 0.4614
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7937 - loss: 0.4302 - val_accuracy: 0.7592 - val_loss: 0.4648
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7902 - loss: 0.4300 - val_accuracy: 0.7567 - val_loss: 0.4689
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7898 - loss: 0.4344 - val_accuracy: 0.7567 - val_loss: 0.4640
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7933 - loss: 0.4299 - val_accuracy: 0.7592 - val_loss: 0.4580
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7898 - loss: 0.4319 - val_accuracy: 0.7517 - val_loss: 0.4823
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7933 - loss: 0.4297 - val_accuracy: 0.7558 - val_loss: 0.4851
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7925 - loss: 0.4371 - val_accuracy: 0.7800 - val_loss: 0.4562
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7946 - loss: 0.4306 - val_accuracy: 0.7683 - val_loss: 0.4587
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7973 - loss: 0.4269 - val_accuracy: 0.7725 - val_loss: 0.4646
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7958 - loss: 0.4315 - val_accuracy: 0.7625 - val_loss: 0.4703
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7896 - loss: 0.4364 - val_accuracy: 0.7625 - val_loss: 0.4659
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7942 - loss: 0.4248 - val_accuracy: 0.7667 - val_loss: 0.4748
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7921 - loss: 0.4324 - val_accuracy: 0.7683 - val_loss: 0.4593
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7967 - loss: 0.4261 - val_accuracy: 0.7742 - val_loss: 0.4582
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7965 - loss: 0.4237 - val_accuracy: 0.7575 - val_loss: 0.4689
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7956 - loss: 0.4283 - val_accuracy: 0.7733 - val_loss: 0.4631
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7915 - loss: 0.4290 - val_accuracy: 0.7633 - val_loss: 0.4579
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7952 - loss: 0.4207 - val_accuracy: 0.7658 - val_loss: 0.4515

# %%
# Evaluate on test data
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test_cnn, y_test)
print(f"Test Loss: {cnn_loss:.4f}, Test Accuracy: {cnn_accuracy:.4f}")

# Make predictions
cnn_predictions = (cnn_model.predict(x_test_cnn) > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7800 - loss: 0.4194
# Test Loss: 0.4194, Test Accuracy: 0.7800
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history_cnn.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='Validation Accuracy')
plt.title('CNN Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation loss
plt.plot(history_cnn.history['loss'], label='Train Loss')
plt.plot(history_cnn.history['val_loss'], label='Validation Loss')
plt.title('CNN Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Confusion matrix
cm = confusion_matrix(y_test, cnn_predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('CNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification report
print(classification_report(y_test, cnn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77      1016
#            1       0.75      0.84      0.79       984
#
#     accuracy                           0.78      2000
#    macro avg       0.78      0.78      0.78      2000
# weighted avg       0.78      0.78      0.78      2000

# %%
# Reshape the data for LSTM
x_train_lstm = np.expand_dims(x_train, axis=1)  # Adding a timestep dimension
x_test_lstm = np.expand_dims(x_test, axis=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7817 - loss: 0.4512 - val_accuracy: 0.7583 - val_loss: 0.4767
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7858 - loss: 0.4463 - val_accuracy: 0.7375 - val_loss: 0.5005
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7825 - loss: 0.4465 - val_accuracy: 0.7633 - val_loss: 0.4726
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7887 - loss: 0.4490 - val_accuracy: 0.7008 - val_loss: 0.5482
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7829 - loss: 0.4506 - val_accuracy: 0.7717 - val_loss: 0.4706
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7788 - loss: 0.4506 - val_accuracy: 0.7650 - val_loss: 0.4753
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7790 - loss: 0.4506 - val_accuracy: 0.7800 - val_loss: 0.4720
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7890 - loss: 0.4431 - val_accuracy: 0.7542 - val_loss: 0.4869
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7927 - loss: 0.4453 - val_accuracy: 0.7625 - val_loss: 0.4745
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7877 - loss: 0.4442 - val_accuracy: 0.7750 - val_loss: 0.4678
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7873 - loss: 0.4452 - val_accuracy: 0.7717 - val_loss: 0.4668
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7912 - loss: 0.4393 - val_accuracy: 0.7625 - val_loss: 0.4702
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7854 - loss: 0.4441 - val_accuracy: 0.7775 - val_loss: 0.4656
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7915 - loss: 0.4393 - val_accuracy: 0.7658 - val_loss: 0.4645
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7846 - loss: 0.4440 - val_accuracy: 0.7683 - val_loss: 0.4663
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7921 - loss: 0.4355 - val_accuracy: 0.7633 - val_loss: 0.4680
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7873 - loss: 0.4406 - val_accuracy: 0.7708 - val_loss: 0.4628
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7931 - loss: 0.4373 - val_accuracy: 0.7675 - val_loss: 0.4667
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7969 - loss: 0.4337 - val_accuracy: 0.7783 - val_loss: 0.4553

# %%
# Evaluate on test data
lstm_loss, lstm_accuracy = lstm_model.evaluate(x_test_lstm, y_test)
print(f"Test Loss: {lstm_loss:.4f}, Test Accuracy: {lstm_accuracy:.4f}")

# Make predictions
lstm_predictions = (lstm_model.predict(x_test_lstm) > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7840 - loss: 0.4312
# Test Loss: 0.4312, Test Accuracy: 0.7840
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
import pickle
pickle.dump(lstm_model, open(r'../FRONTEND/lstm.pkl', 'wb'))

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history_lstm.history['accuracy'], label='Train Accuracy')
plt.plot(history_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.title('LSTM Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation loss
plt.plot(history_lstm.history['loss'], label='Train Loss')
plt.plot(history_lstm.history['val_loss'], label='Validation Loss')
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Confusion matrix
cm = confusion_matrix(y_test, lstm_predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('LSTM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification report
print(classification_report(y_test, lstm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.70      0.77      1016
#            1       0.74      0.87      0.80       984
#
#     accuracy                           0.78      2000
#    macro avg       0.79      0.79      0.78      2000
# weighted avg       0.79      0.78      0.78      2000

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Flatten, Dense, Dropout, Reshape
from sklearn.preprocessing import LabelEncoder

# Define the CNN-LSTM model
def build_cnn_lstm_model(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', padding='same', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(32, kernel_size=3, activation='relu', padding='same'),
        MaxPooling1D(pool_size=2),
        Reshape((input_shape[0] // 4, 32)),  # Adjust dimensions for LSTM
        LSTM(50, return_sequences=False),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Encode the y values
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Epoch 72/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8325 - loss: 0.3748 - val_accuracy: 0.8033 - val_loss: 0.4105
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8377 - loss: 0.3680 - val_accuracy: 0.8000 - val_loss: 0.4088
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8421 - loss: 0.3605 - val_accuracy: 0.8342 - val_loss: 0.3900
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8394 - loss: 0.3610 - val_accuracy: 0.8333 - val_loss: 0.3780
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8429 - loss: 0.3642 - val_accuracy: 0.8467 - val_loss: 0.3659
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8406 - loss: 0.3562 - val_accuracy: 0.8525 - val_loss: 0.3625
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8485 - loss: 0.3445 - val_accuracy: 0.8433 - val_loss: 0.3606
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8573 - loss: 0.3284 - val_accuracy: 0.8392 - val_loss: 0.3817
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8535 - loss: 0.3345 - val_accuracy: 0.8258 - val_loss: 0.3820
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8475 - loss: 0.3465 - val_accuracy: 0.8183 - val_loss: 0.3878
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8587 - loss: 0.3320 - val_accuracy: 0.8575 - val_loss: 0.3415
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8612 - loss: 0.3262 - val_accuracy: 0.8575 - val_loss: 0.3536
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8542 - loss: 0.3369 - val_accuracy: 0.8475 - val_loss: 0.3548
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8606 - loss: 0.3204 - val_accuracy: 0.8483 - val_loss: 0.3512
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8615 - loss: 0.3203 - val_accuracy: 0.8833 - val_loss: 0.3228
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8521 - loss: 0.3447 - val_accuracy: 0.8350 - val_loss: 0.3876
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8708 - loss: 0.3154 - val_accuracy: 0.8508 - val_loss: 0.3367
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8744 - loss: 0.3000 - val_accuracy: 0.8633 - val_loss: 0.3307
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8798 - loss: 0.2916 - val_accuracy: 0.8558 - val_loss: 0.3253
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8769 - loss: 0.2956 - val_accuracy: 0.8892 - val_loss: 0.3011
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8533 - loss: 0.3262 - val_accuracy: 0.8767 - val_loss: 0.3133
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8852 - loss: 0.2830 - val_accuracy: 0.8600 - val_loss: 0.3223
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8827 - loss: 0.2877 - val_accuracy: 0.8783 - val_loss: 0.2944
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8858 - loss: 0.2805 - val_accuracy: 0.8900 - val_loss: 0.2919
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8942 - loss: 0.2665 - val_accuracy: 0.8933 - val_loss: 0.2740
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8852 - loss: 0.2812 - val_accuracy: 0.8833 - val_loss: 0.2902
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8856 - loss: 0.2760 - val_accuracy: 0.8883 - val_loss: 0.2873
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8885 - loss: 0.2706 - val_accuracy: 0.8925 - val_loss: 0.2850
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8892 - loss: 0.2638 - val_accuracy: 0.8967 - val_loss: 0.2649

# %%
# Evaluate the model on test data
test_loss, test_accuracy = cnn_lstm_model.evaluate(x_test_cnn, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9050 - loss: 0.2588
# Test Accuracy: 90.50%

# %%
import pickle
pickle.dump(cnn_lstm_model, open(r'../FRONTEND/cnn_lstm.pkl', 'wb'))

# %%
# Plot accuracy curves
plt.figure(figsize=(8, 6))
plt.plot(history_cnn_lstm.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
# Plot loss curves
plt.figure(figsize=(8, 6))
plt.plot(history_cnn_lstm.history['loss'], label='Train Loss')
plt.plot(history_cnn_lstm.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Generate confusion matrix
y_pred = cnn_lstm_model.predict(x_test_cnn)
y_pred_classes = (y_pred > 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
